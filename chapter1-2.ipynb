# %%
import numpy as np
import torch

a = np.array([3]).tolist()
torch.tensor
# Out:
# tensor([3])

# %%
#import torch
torch.cuda.is_available()

torch.from_numpy(a)
# Out:
# A module that was compiled using NumPy 1.x cannot be run in
# NumPy 2.0.0 as it may crash. To support both 1.x and 2.x
# versions of NumPy, modules must be compiled with NumPy 2.0.
# Some module may need to rebuild instead e.g. with 'pybind11>=2.12'.
#
# If you are a user of the module, the easiest solution will be to
# downgrade to 'numpy<2' or try to upgrade the affected module.
# We expect that some modules will need time to support NumPy 2.
#
# Traceback (most recent call last):  File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "d:\pytorch\.venv\Lib\site-packages\ipykernel_launcher.py", line 18, in <module>
#     app.launch_new_instance()
#   File "d:\pytorch\.venv\Lib\site-packages\traitlets\config\application.py", line 1075, in launch_instance
#     app.start()
#   File "d:\pytorch\.venv\Lib\site-packages\ipykernel\kernelapp.py", line 739, in start
#     self.io_loop.start()
#   File "d:\pytorch\.venv\Lib\site-packages\tornado\platform\asyncio.py", line 205, in start
#     self.asyncio_loop.run_forever()
#   File "C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.12_3.12.1264.0_x64__qbz5n2kfra8p0\Lib\asyncio\base_events.py", line 641, in run_forever
#     self._run_once()
#   File "C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.12_3.12.1264.0_x64__qbz5n2kfra8p0\Lib\asyncio\base_events.py", line 1987, in _run_once
#     handle._run()
#   File "C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.12_3.12.1264.0_x64__qbz5n2kfra8p0\Lib\asyncio\events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "d:\pytorch\.venv\Lib\site-packages\ipykernel\kernelbase.py", line 545, in dispatch_queue
#     await self.process_one()
#   File "d:\pytorch\.venv\Lib\site-packages\ipykernel\kernelbase.py", line 534, in process_one
#     await dispatch(*args)
#   File "d:\pytorch\.venv\Lib\site-packages\ipykernel\kernelbase.py", line 437, in dispatch_shell
#     await result
#   File "d:\pytorch\.venv\Lib\site-packages\ipykernel\ipkernel.py", line 362, in execute_request
#     await super().execute_request(stream, ident, parent)
#   File "d:\pytorch\.venv\Lib\site-packages\ipykernel\kernelbase.py", line 778, in execute_request
#     reply_content = await reply_content
#   File "d:\pytorch\.venv\Lib\site-packages\ipykernel\ipkernel.py", line 449, in do_execute
#     res = shell.run_cell(
#   File "d:\pytorch\.venv\Lib\site-packages\ipykernel\zmqshell.py", line 549, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "d:\pytorch\.venv\Lib\site-packages\IPython\core\interactiveshell.py", line 3075, in run_cell
#     result = self._run_cell(
#   File "d:\pytorch\.venv\Lib\site-packages\IPython\core\interactiveshell.py", line 3130, in _run_cell
#     result = runner(coro)
#   File "d:\pytorch\.venv\Lib\site-packages\IPython\core\async_helpers.py", line 128, in _pseudo_sync_runner
#     coro.send(None)
#   File "d:\pytorch\.venv\Lib\site-packages\IPython\core\interactiveshell.py", line 3334, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "d:\pytorch\.venv\Lib\site-packages\IPython\core\interactiveshell.py", line 3517, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "d:\pytorch\.venv\Lib\site-packages\IPython\core\interactiveshell.py", line 3577, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\user\AppData\Local\Temp\ipykernel_23228\4205439877.py", line 4, in <module>
#     torch.from_numpy(a)
# C:\Users\user\AppData\Local\Temp\ipykernel_23228\4205439877.py:4: UserWarning: Failed to initialize NumPy: _ARRAY_API not found (Triggered internally at ..\torch\csrc\utils\tensor_numpy.cpp:84.)
#   torch.from_numpy(a)
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[5], line 4
#       1 #import torch
#       2 torch.cuda.is_available()
# ----> 4 torch.from_numpy(a)
#
# RuntimeError: Numpy is not available

# %%
from torchvision import models
dir(models)

# %%
alexnet = models.AlexNet()
resnet = models.resnet101()
resnet

# %%
from torchvision import transforms
preprocess = transforms.Compose([transforms.Resize(256),transforms.CenterCrop(224),transforms.ToTensor(),transforms.Normalize(mean=[0.485,0.456,0.406],std=[0.229,0.224,0.225])])

from PIL import Image
img = Image.open( r"C:\Users\user\Pictures\배경화면\깡과총.png")

img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=2160x1215>

# %%
import numpy as np
img_t = preprocess(img)

import torch
batch_t = torch.unsqueeze(img_t,0)

resnet.eval
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[9], line 2
#       1 import numpy as np
# ----> 2 img_t = preprocess(img)
#       4 import torch
#       5 batch_t = torch.unsqueeze(img_t,0)
#
# File d:\pytorch\.venv\Lib\site-packages\torchvision\transforms\transforms.py:95, in Compose.__call__(self, img)
#      93 def __call__(self, img):
#      94     for t in self.transforms:
# ---> 95         img = t(img)
#      96     return img
#
# File d:\pytorch\.venv\Lib\site-packages\torchvision\transforms\transforms.py:137, in ToTensor.__call__(self, pic)
#     129 def __call__(self, pic):
#     130     """
#     131     Args:
#     132         pic (PIL Image or numpy.ndarray): Image to be converted to tensor.
#    (...)
#     135         Tensor: Converted image.
#     136     """
# --> 137     return F.to_tensor(pic)
#
# File d:\pytorch\.venv\Lib\site-packages\torchvision\transforms\functional.py:168, in to_tensor(pic)
#     166 # handle PIL Image
#     167 mode_to_nptype = {"I": np.int32, "I;16" if sys.byteorder == "little" else "I;16B": np.int16, "F": np.float32}
# --> 168 img = torch.from_numpy(np.array(pic, mode_to_nptype.get(pic.mode, np.uint8), copy=True))
#     170 if pic.mode == "1":
#     171     img = 255 * img
#
# RuntimeError: Numpy is not available

# %%
import torch
import numpy as np

print(f"PyTorch version: {torch.__version__}")
print(f"NumPy version: {np.__version__}")

# %%
import numpy as np
import torch
from torchvision import transforms
from PIL import Image

# 이미지 로드
img = Image.open(r"C:\Users\user\Pictures\배경화면\깡과총.png")

# 전처리 파이프라인
preprocess = transforms.Compose([
    transforms.Resize(256),
    transforms.CenterCrop(224),
    transforms.ToTensor(),
])

# 전처리 적용
try:
    img_t = preprocess(img)
    batch_t = torch.unsqueeze(img_t, 0)
except RuntimeError as e:
    print(f"RuntimeError: {e}")

# numpy가 제대로 로드되었는지 확인
print(np.__version__)

# %%
import numpy as np
import torch
from torchvision import transforms
from PIL import Image

# 간단한 numpy 연산
try:
    a = np.array([1, 2, 3])
    print("Numpy array:", a)
except Exception as e:
    print("Numpy error:", e)

# 간단한 torchvision 변환
try:
    img = Image.new('RGB', (100, 100))
    transform = transforms.ToTensor()
    img_tensor = transform(img)
    print("Torchvision tensor size:", img_tensor.size())
except Exception as e:
    print("Torchvision error:", e)
